# %% [markdown]
# # INM707 Coursework - Task 2
# Selim Bayrak / 200056225

# %% [markdown]
# ## Model Training & Evaluation with Experiment Files
#
# Tests are carried out automatically by task2_experiment.py file which uses the test cases and hyper-parameters entered in task2_tests.yaml file. There are 26 pre-defined tests used for evaluation. The graphs can be seen at the end of the iterations.

# %%
from task2_experiment import run_tests

# %%
results = run_tests()
# Out:
# Test No : 10 Iteration batch : 1 Mean reward : -232.44
# Test No : 10 Iteration batch : 2 Mean reward : -108.14
# Test No : 10 Iteration batch : 3 Mean reward : -19.86
# Test No : 10 Iteration batch : 4 Mean reward : 43.02
# Test No : 10 Iteration batch : 5 Mean reward : 82.08
# Test No : 10 Iteration batch : 6 Mean reward : 121.74
# Test No : 10 Iteration batch : 7 Mean reward : 184.82
# Test No : 10 Iteration batch : 8 Mean reward : 131.76
# Test No : 10 Iteration batch : 9 Mean reward : 132.74
# Test No : 10 Iteration batch : 10 Mean reward : 135.88
# Test No : 10 Iteration batch : 11 Mean reward : 154.02
# Test No : 10 Iteration batch : 12 Mean reward : 137.84
# Test No : 10 Iteration batch : 13 Mean reward : 133.62
# Test No : 10 Iteration batch : 14 Mean reward : 135.22
# Test No : 10 Iteration batch : 15 Mean reward : 106.54
# Test No : 10 Iteration batch : 16 Mean reward : 109.0
# Test No : 10 Iteration batch : 17 Mean reward : 108.28
# ...

# %%
results.head()
# Out:
#    test_no  env_size  gamma  ...  iters Last Average Score  No of Q-Learning episodes
# 0       10        11   0.99  ...    500             592.36                      50000
# 1       20        10   0.99  ...    500             486.56                      50000
# 2       25        11   0.99  ...    500             594.78                      50000
#
# [3 rows x 12 columns]
