# %% [markdown]
# # INM707 Coursework - Task 4
# ### Selim Bayrak / 200056225 & Kristina Semenyuk / 200036364

# %% [markdown]
# ## Actor-Critic Implementation

# %% [markdown]
# Training and evaluation is conducted automatically by experiment.py file which uses the test cases and hyper-parameters entered in tests.yaml file. There are 14 pre-defined tests used for evaluation. The graphs can be seen at the end of the iterations.

# %%
from experiment import run_tests

# %%
df = run_tests()
# Out:
# Episode: 1 	 ¦ 	 Reward 31.0
# Episode: 11 	 ¦ 	 Reward 17.0
# Episode: 21 	 ¦ 	 Reward 23.6
# Episode: 31 	 ¦ 	 Reward 33.3
# Episode: 41 	 ¦ 	 Reward 20.9
# Episode: 51 	 ¦ 	 Reward 32.7
# Episode: 61 	 ¦ 	 Reward 35.7
# Episode: 71 	 ¦ 	 Reward 37.2
# Episode: 81 	 ¦ 	 Reward 36.5
# Episode: 91 	 ¦ 	 Reward 41.9
# Episode: 101 	 ¦ 	 Reward 70.3
# Episode: 111 	 ¦ 	 Reward 66.4
# Episode: 121 	 ¦ 	 Reward 75.3
# Episode: 131 	 ¦ 	 Reward 102.4
# Episode: 141 	 ¦ 	 Reward 66.3
# Episode: 151 	 ¦ 	 Reward 155.4
# Episode: 161 	 ¦ 	 Reward 166.4
# Episode: 171 	 ¦ 	 Reward 191.6
# Episode: 181 	 ¦ 	 Reward 136.6
# Episode: 191 	 ¦ 	 Reward 118.6
# Episode: 201 	 ¦ 	 Reward 139.4
# Episode: 211 	 ¦ 	 Reward 145.7
# Episode: 221 	 ¦ 	 Reward 111.4
# Episode: 231 	 ¦ 	 Reward 113.7
# Episode: 241 	 ¦ 	 Reward 143.0
# Episode: 251 	 ¦ 	 Reward 145.9
# Episode: 261 	 ¦ 	 Reward 174.7
# Episode: 271 	 ¦ 	 Reward 156.5
# Episode: 281 	 ¦ 	 Reward 166.0
# Episode: 291 	 ¦ 	 Reward 151.2
# ...

# %%
from IPython.display import display
display(df)
# Out:
#     test_no          env  hidden_size  ...   save  Episode  Max average score
# 0         1  CartPole-v0           64  ...  False      430                200
# 1         2  CartPole-v0          128  ...  False      280                200
# 2         3  CartPole-v0          256  ...  False      840                200
# 3         4  CartPole-v0          256  ...  False      510                200
# 4         5  CartPole-v0          256  ...  False      210                200
# 5         6  CartPole-v0          256  ...  False      350                200
# 6         7  CartPole-v0          256  ...  False      120                200
# 7         8  CartPole-v0          256  ...  False      230                200
# 8         9  CartPole-v0          256  ...  False      240                200
# 9        10  CartPole-v0          256  ...  False      150                200
# 10       11  CartPole-v0          256  ...  False      300                200
# ...
